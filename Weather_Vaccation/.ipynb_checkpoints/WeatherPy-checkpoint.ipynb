# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | klyuchi
# Processing Record 2 of Set 1 | anadyr
# Processing Record 3 of Set 1 | yantai
# Processing Record 4 of Set 1 | 'ibri
# City not found. Skipping...
# Processing Record 5 of Set 1 | luderitz
# Processing Record 6 of Set 1 | hatillo
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | hawaiian paradise park
# Processing Record 9 of Set 1 | jalpa de mendez
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | palikir - national government center
# Processing Record 12 of Set 1 | ende
# Processing Record 13 of Set 1 | madera
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | hami
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | bemidji
# Processing Record 21 of Set 1 | altus
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | margaret river
# Processing Record 24 of Set 1 | tieling
# Processing Record 25 of Set 1 | gamba
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | paita
# Processing Record 28 of Set 1 | happy valley-goose bay
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | san martin de valdeiglesias
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | glace bay
# Processing Record 33 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 1 | holualoa
# Processing Record 35 of Set 1 | ishim
# Processing Record 36 of Set 1 | adamstown
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | port isabel
# Processing Record 39 of Set 1 | okigwe
# Processing Record 40 of Set 1 | port hedland
# Processing Record 41 of Set 1 | wenchang
# Processing Record 42 of Set 1 | yacuiba
# Processing Record 43 of Set 1 | kirakira
# Processing Record 44 of Set 1 | polyarnyy
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | kingston
# Processing Record 47 of Set 1 | el paujil
# Processing Record 48 of Set 1 | tangalle
# Processing Record 49 of Set 1 | ario de rosales
# Processing Record 50 of Set 1 | port mathurin
# Processing Record 0 of Set 2 | puerto natales
# Processing Record 1 of Set 2 | lihue
# Processing Record 2 of Set 2 | isafjordur
# Processing Record 3 of Set 2 | waitangi
# Processing Record 4 of Set 2 | acapulco de juarez
# Processing Record 5 of Set 2 | carbonear
# Processing Record 6 of Set 2 | tamanrasset
# Processing Record 7 of Set 2 | vilyuchinsk
# Processing Record 8 of Set 2 | papao
# Processing Record 9 of Set 2 | tual
# Processing Record 10 of Set 2 | west island
# Processing Record 11 of Set 2 | ziniare
# Processing Record 12 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | suva
# Processing Record 16 of Set 2 | portoferraio
# Processing Record 17 of Set 2 | menongue
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | embarcacion
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | mount vernon
# Processing Record 22 of Set 2 | hovd
# Processing Record 23 of Set 2 | ust-nera
# Processing Record 24 of Set 2 | utrik
# Processing Record 25 of Set 2 | mahina
# Processing Record 26 of Set 2 | bishkul
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | olonkinbyen
# Processing Record 29 of Set 2 | keflavik
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | pangody
# Processing Record 32 of Set 2 | greymouth
# Processing Record 33 of Set 2 | mount pearl
# Processing Record 34 of Set 2 | fairfield
# Processing Record 35 of Set 2 | la passe
# Processing Record 36 of Set 2 | novyy urengoy
# Processing Record 37 of Set 2 | lata
# Processing Record 38 of Set 2 | grand falls-windsor
# Processing Record 39 of Set 2 | badger
# Processing Record 40 of Set 2 | young
# Processing Record 41 of Set 2 | walvis bay
# Processing Record 42 of Set 2 | chonchi
# Processing Record 43 of Set 2 | gueltat zemmour
# City not found. Skipping...
# Processing Record 44 of Set 2 | stanley
# Processing Record 45 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | shirvan
# Processing Record 48 of Set 2 | huaidian
# Processing Record 49 of Set 2 | la roque-d'antheron
# City not found. Skipping...
# Processing Record 0 of Set 3 | whitehorse
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | minas de marcona
# Processing Record 3 of Set 3 | tanjung selor
# City not found. Skipping...
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | ola
# Processing Record 6 of Set 3 | qaqortoq
# Processing Record 7 of Set 3 | barakani
# Processing Record 8 of Set 3 | blagoevgrad
# Processing Record 9 of Set 3 | papatowai
# Processing Record 10 of Set 3 | blackmans bay
# Processing Record 11 of Set 3 | thief river falls
# Processing Record 12 of Set 3 | edinburgh of the seven seas
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | banbury
# Processing Record 15 of Set 3 | constantia
# Processing Record 16 of Set 3 | queenstown
# Processing Record 17 of Set 3 | baja
# Processing Record 18 of Set 3 | portland
# Processing Record 19 of Set 3 | larache
# Processing Record 20 of Set 3 | bayeux
# Processing Record 21 of Set 3 | taveta
# Processing Record 22 of Set 3 | port maria
# Processing Record 23 of Set 3 | rongelap
# Processing Record 24 of Set 3 | vorgashor
# Processing Record 25 of Set 3 | balikpapan
# Processing Record 26 of Set 3 | kosciusko
# Processing Record 27 of Set 3 | palmer
# Processing Record 28 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 29 of Set 3 | kapa'a
# Processing Record 30 of Set 3 | ta`u
# Processing Record 31 of Set 3 | san antonio de pale
# Processing Record 32 of Set 3 | syanno
# Processing Record 33 of Set 3 | flying fish cove
# Processing Record 34 of Set 3 | arafat
# Processing Record 35 of Set 3 | tsiombe
# Processing Record 36 of Set 3 | jieshi
# Processing Record 37 of Set 3 | twentynine palms
# Processing Record 38 of Set 3 | st. john's
# Processing Record 39 of Set 3 | naha
# Processing Record 40 of Set 3 | belmonte
# Processing Record 41 of Set 3 | mazatlan
# Processing Record 42 of Set 3 | conde
# Processing Record 43 of Set 3 | timana
# Processing Record 44 of Set 3 | newman
# Processing Record 45 of Set 3 | wailua homesteads
# Processing Record 46 of Set 3 | shenkursk
# Processing Record 47 of Set 3 | margherita
# Processing Record 48 of Set 3 | yazman
# Processing Record 49 of Set 3 | hermanus
# Processing Record 0 of Set 4 | las khorey
# Processing Record 1 of Set 4 | san martin
# Processing Record 2 of Set 4 | victoria point
# Processing Record 3 of Set 4 | castillos
# Processing Record 4 of Set 4 | trondheim
# Processing Record 5 of Set 4 | salinopolis
# Processing Record 6 of Set 4 | ceerigaabo
# Processing Record 7 of Set 4 | remire-montjoly
# Processing Record 8 of Set 4 | port saint john's
# Processing Record 9 of Set 4 | kiruna
# Processing Record 10 of Set 4 | manay
# Processing Record 11 of Set 4 | tambo
# Processing Record 12 of Set 4 | college
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | rio grande
# Processing Record 15 of Set 4 | puerto baquerizo moreno
# Processing Record 16 of Set 4 | punta arenas
# Processing Record 17 of Set 4 | kuanda
# Processing Record 18 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 19 of Set 4 | uturoa
# Processing Record 20 of Set 4 | tazovsky
# Processing Record 21 of Set 4 | beira
# Processing Record 22 of Set 4 | asyqata
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | jiwani
# Processing Record 25 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 4 | north amherst
# Processing Record 27 of Set 4 | ghat
# Processing Record 28 of Set 4 | kuytun
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | fort st. john
# Processing Record 31 of Set 4 | hobyo
# Processing Record 32 of Set 4 | nieuw amsterdam
# Processing Record 33 of Set 4 | tweed heads
# Processing Record 34 of Set 4 | monroeville
# Processing Record 35 of Set 4 | box elder
# Processing Record 36 of Set 4 | sebastopol
# Processing Record 37 of Set 4 | puerto ayora
# Processing Record 38 of Set 4 | kirensk
# Processing Record 39 of Set 4 | bulgan
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | kone
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | codrington
# Processing Record 44 of Set 4 | usinsk
# Processing Record 45 of Set 4 | dikhil
# Processing Record 46 of Set 4 | margate
# Processing Record 47 of Set 4 | kavaratti
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | tazacorte
# Processing Record 0 of Set 5 | kayyerkan
# Processing Record 1 of Set 5 | vanimo
# Processing Record 2 of Set 5 | ushuaia
# Processing Record 3 of Set 5 | karyes
# Processing Record 4 of Set 5 | kitimat
# Processing Record 5 of Set 5 | tofol
# Processing Record 6 of Set 5 | faya-largeau
# Processing Record 7 of Set 5 | fale old settlement
# Processing Record 8 of Set 5 | pizarro
# Processing Record 9 of Set 5 | bejubang dua
# City not found. Skipping...
# Processing Record 10 of Set 5 | bargaal
# Processing Record 11 of Set 5 | kashgar
# Processing Record 12 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 5 | lazaro cardenas
# Processing Record 14 of Set 5 | biltine
# Processing Record 15 of Set 5 | punta del este
# Processing Record 16 of Set 5 | mejit
# Processing Record 17 of Set 5 | oliveira dos brejinhos
# Processing Record 18 of Set 5 | loen
# Processing Record 19 of Set 5 | tolanaro
# Processing Record 20 of Set 5 | hotan
# Processing Record 21 of Set 5 | laguna
# Processing Record 22 of Set 5 | balabac
# Processing Record 23 of Set 5 | santa cruz
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | dabeiba
# Processing Record 26 of Set 5 | nakonde
# Processing Record 27 of Set 5 | morwell
# Processing Record 28 of Set 5 | punta alta
# Processing Record 29 of Set 5 | bubaque
# Processing Record 30 of Set 5 | vallenar
# Processing Record 31 of Set 5 | aasiaat
# Processing Record 32 of Set 5 | dar naim
# City not found. Skipping...
# Processing Record 33 of Set 5 | tura
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | dhuusamarreeb
# Processing Record 36 of Set 5 | zhelezinka
# Processing Record 37 of Set 5 | vernon
# Processing Record 38 of Set 5 | djambala
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | atafu village
# Processing Record 41 of Set 5 | rovaniemi
# Processing Record 42 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 5 | hammerfest
# Processing Record 44 of Set 5 | kievka
# Processing Record 45 of Set 5 | bandar-e anzali
# Processing Record 46 of Set 5 | pisco
# Processing Record 47 of Set 5 | ad dabbah
# Processing Record 48 of Set 5 | coari
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 0 of Set 6 | sao vicente
# Processing Record 1 of Set 6 | howrah
# Processing Record 2 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 6 | dubbo
# Processing Record 4 of Set 6 | sidney
# Processing Record 5 of Set 6 | suratgarh
# Processing Record 6 of Set 6 | kyabram
# Processing Record 7 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 8 of Set 6 | emerald
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | visakhapatnam
# Processing Record 12 of Set 6 | al jawf
# Processing Record 13 of Set 6 | montepuez
# Processing Record 14 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 15 of Set 6 | al ghayzah
# Processing Record 16 of Set 6 | egilsstadir
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | timbuktu
# Processing Record 20 of Set 6 | preobrazheniye
# Processing Record 21 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 6 | charters towers
# Processing Record 23 of Set 6 | ouesso
# Processing Record 24 of Set 6 | znamenskoye
# Processing Record 25 of Set 6 | kochubey
# Processing Record 26 of Set 6 | invercargill
# Processing Record 27 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | roma
# Processing Record 29 of Set 6 | callao
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | senanga
# Processing Record 32 of Set 6 | banfora
# Processing Record 33 of Set 6 | melekeok village
# Processing Record 34 of Set 6 | antsiranana
# Processing Record 35 of Set 6 | wajir
# Processing Record 36 of Set 6 | puno
# Processing Record 37 of Set 6 | kiama
# Processing Record 38 of Set 6 | hirara
# Processing Record 39 of Set 6 | bad blankenburg
# Processing Record 40 of Set 6 | bocas del toro
# Processing Record 41 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 42 of Set 6 | nizhneudinsk
# Processing Record 43 of Set 6 | green cove springs
# Processing Record 44 of Set 6 | booue
# Processing Record 45 of Set 6 | naze
# Processing Record 46 of Set 6 | dwarka
# Processing Record 47 of Set 6 | katabu
# Processing Record 48 of Set 6 | labrador city
# Processing Record 49 of Set 6 | vadso
# Processing Record 0 of Set 7 | brak
# Processing Record 1 of Set 7 | agat village
# Processing Record 2 of Set 7 | boa vista
# Processing Record 3 of Set 7 | bac lieu
# Processing Record 4 of Set 7 | juruti
# Processing Record 5 of Set 7 | san luis de la loma
# Processing Record 6 of Set 7 | natal
# Processing Record 7 of Set 7 | nongstoin
# Processing Record 8 of Set 7 | kimbe
# Processing Record 9 of Set 7 | dordrecht
# Processing Record 10 of Set 7 | northam
# Processing Record 11 of Set 7 | acarau
# Processing Record 12 of Set 7 | colares
# Processing Record 13 of Set 7 | doaba
# Processing Record 14 of Set 7 | sinop
# Processing Record 15 of Set 7 | afaahiti
# Processing Record 16 of Set 7 | barra de santo antonio
# Processing Record 17 of Set 7 | iskateley
# Processing Record 18 of Set 7 | porto novo
# Processing Record 19 of Set 7 | izhmorskiy
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | astara
# Processing Record 22 of Set 7 | nola
# Processing Record 23 of Set 7 | mana
# Processing Record 24 of Set 7 | okhotsk
# Processing Record 25 of Set 7 | mrakovo
# Processing Record 26 of Set 7 | vozhega
# Processing Record 27 of Set 7 | caburan
# Processing Record 28 of Set 7 | kabansk
# Processing Record 29 of Set 7 | severo-yeniseyskiy
# Processing Record 30 of Set 7 | alofi
# Processing Record 31 of Set 7 | kani keli
# Processing Record 32 of Set 7 | matanzas
# Processing Record 33 of Set 7 | olyokminsk
# Processing Record 34 of Set 7 | sao felix do xingu
# Processing Record 35 of Set 7 | new norfolk
# Processing Record 36 of Set 7 | hadibu
# Processing Record 37 of Set 7 | sidi slimane
# Processing Record 38 of Set 7 | ingeniero guillermo n. juarez
# Processing Record 39 of Set 7 | amlapura
# Processing Record 40 of Set 7 | yanam
# Processing Record 41 of Set 7 | abepura
# Processing Record 42 of Set 7 | lamesa
# Processing Record 43 of Set 7 | berdigestyakh
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | tabou
# Processing Record 46 of Set 7 | pemangkat
# Processing Record 47 of Set 7 | kidal
# Processing Record 48 of Set 7 | brixham
# Processing Record 49 of Set 7 | namibe
# Processing Record 0 of Set 8 | saldanha
# Processing Record 1 of Set 8 | grand rapids
# Processing Record 2 of Set 8 | boyes hot springs
# Processing Record 3 of Set 8 | arar
# Processing Record 4 of Set 8 | sinabang
# Processing Record 5 of Set 8 | shache
# Processing Record 6 of Set 8 | zag
# Processing Record 7 of Set 8 | corumba
# Processing Record 8 of Set 8 | turpan
# Processing Record 9 of Set 8 | altamira
# Processing Record 10 of Set 8 | rengasdengklok
# Processing Record 11 of Set 8 | ciudad lazaro cardenas
# Processing Record 12 of Set 8 | magadan
# Processing Record 13 of Set 8 | island harbour
# Processing Record 14 of Set 8 | eskisehir
# Processing Record 15 of Set 8 | birjand
# Processing Record 16 of Set 8 | zaozersk
# Processing Record 17 of Set 8 | saint-pierre
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | west bay
# Processing Record 20 of Set 8 | chaykovskiy
# Processing Record 21 of Set 8 | muang xay
# Processing Record 22 of Set 8 | richards bay
# Processing Record 23 of Set 8 | las heras
# Processing Record 24 of Set 8 | batala
# Processing Record 25 of Set 8 | guerrero negro
# Processing Record 26 of Set 8 | pulsano
# Processing Record 27 of Set 8 | leava
# Processing Record 28 of Set 8 | dampit
# Processing Record 29 of Set 8 | al kharijah
# Processing Record 30 of Set 8 | baiyin
# Processing Record 31 of Set 8 | ondjiva
# Processing Record 32 of Set 8 | onguday
# Processing Record 33 of Set 8 | almeirim
# Processing Record 34 of Set 8 | cabedelo
# Processing Record 35 of Set 8 | dudinka
# Processing Record 36 of Set 8 | sandnessjoen
# Processing Record 37 of Set 8 | el bauga
# Processing Record 38 of Set 8 | madzhalis
# Processing Record 39 of Set 8 | sarandi del yi
# Processing Record 40 of Set 8 | shingu
# Processing Record 41 of Set 8 | tralee
# Processing Record 42 of Set 8 | strezhevoy
# Processing Record 43 of Set 8 | kamyzyak
# Processing Record 44 of Set 8 | kirgiz-miyaki
# Processing Record 45 of Set 8 | kenora
# Processing Record 46 of Set 8 | clodomira
# Processing Record 47 of Set 8 | gemena
# Processing Record 48 of Set 8 | nizhniy kuranakh
# Processing Record 49 of Set 8 | haiku-pauwela
# Processing Record 0 of Set 9 | changyon
# Processing Record 1 of Set 9 | catio
# Processing Record 2 of Set 9 | ust'-kulom
# Processing Record 3 of Set 9 | lionel town
# Processing Record 4 of Set 9 | monrovia
# Processing Record 5 of Set 9 | kita
# Processing Record 6 of Set 9 | nadym
# Processing Record 7 of Set 9 | nova sintra
# Processing Record 8 of Set 9 | raton
# Processing Record 9 of Set 9 | novoishimskiy
# Processing Record 10 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 11 of Set 9 | udachny
# Processing Record 12 of Set 9 | nar'yan-mar
# Processing Record 13 of Set 9 | saksaul'skiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | taulaga
# Processing Record 15 of Set 9 | ivdel'
# Processing Record 16 of Set 9 | kattivakkam
# Processing Record 17 of Set 9 | geraldton
# Processing Record 18 of Set 9 | las varas
# Processing Record 19 of Set 9 | mao
# Processing Record 20 of Set 9 | boyolangu
# Processing Record 21 of Set 9 | manokwari
# Processing Record 22 of Set 9 | tidjikja
# Processing Record 23 of Set 9 | borogontsy
# Processing Record 24 of Set 9 | auburn
# Processing Record 25 of Set 9 | gulf breeze
# Processing Record 26 of Set 9 | chibougamau
# Processing Record 27 of Set 9 | muisne
# Processing Record 28 of Set 9 | kalat
# Processing Record 29 of Set 9 | verkhov'ye
# Processing Record 30 of Set 9 | pontianak
# Processing Record 31 of Set 9 | basco
# Processing Record 32 of Set 9 | marsh harbour
# Processing Record 33 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 34 of Set 9 | belyy yar
# Processing Record 35 of Set 9 | parambu
# Processing Record 36 of Set 9 | menomonie
# Processing Record 37 of Set 9 | vila velha
# Processing Record 38 of Set 9 | kruisfontein
# Processing Record 39 of Set 9 | ingeniero jacobacci
# Processing Record 40 of Set 9 | jinka
# Processing Record 41 of Set 9 | zayed city
# Processing Record 42 of Set 9 | pandan
# Processing Record 43 of Set 9 | tanjung sepat
# Processing Record 44 of Set 9 | tomatlan
# Processing Record 45 of Set 9 | coquimbo
# Processing Record 46 of Set 9 | ilam
# Processing Record 47 of Set 9 | hilo
# Processing Record 48 of Set 9 | dapa
# Processing Record 49 of Set 9 | cerritos
# Processing Record 0 of Set 10 | kailua-kona
# Processing Record 1 of Set 10 | heroica caborca
# Processing Record 2 of Set 10 | alice springs
# Processing Record 3 of Set 10 | sisimiut
# Processing Record 4 of Set 10 | touros
# Processing Record 5 of Set 10 | bilajer
# Processing Record 6 of Set 10 | kamphaeng phet
# Processing Record 7 of Set 10 | jakhal
# Processing Record 8 of Set 10 | key west
# Processing Record 9 of Set 10 | yatou
# Processing Record 10 of Set 10 | vredenburg
# City not found. Skipping...
# Processing Record 11 of Set 10 | cockburn town
# Processing Record 12 of Set 10 | santa maria de cayon
# Processing Record 13 of Set 10 | pahrump
# Processing Record 14 of Set 10 | zarichne
# Processing Record 15 of Set 10 | kosong
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | san julian
# Processing Record 18 of Set 10 | piacabucu
# Processing Record 19 of Set 10 | grand-lahou
# Processing Record 20 of Set 10 | brisas de zicatela
# Processing Record 21 of Set 10 | brookings
# Processing Record 22 of Set 10 | naifaru
# Processing Record 23 of Set 10 | praia da vitoria
# Processing Record 24 of Set 10 | fort mcmurray
# Processing Record 25 of Set 10 | kavieng
# Processing Record 26 of Set 10 | rio preto da eva
# Processing Record 27 of Set 10 | kedrovyy
# Processing Record 28 of Set 10 | vavoua
# Processing Record 29 of Set 10 | darwin
# Processing Record 30 of Set 10 | kolonia
# Processing Record 31 of Set 10 | turkmenbasy
# Processing Record 32 of Set 10 | shetpe
# Processing Record 33 of Set 10 | ashchysay
# Processing Record 34 of Set 10 | inekar
# City not found. Skipping...
# Processing Record 35 of Set 10 | bereket
# Processing Record 36 of Set 10 | kaba
# Processing Record 37 of Set 10 | el calafate
# Processing Record 38 of Set 10 | antofagasta
# Processing Record 39 of Set 10 | kikvidze
# Processing Record 40 of Set 10 | syas'stroy
# Processing Record 41 of Set 10 | lander
# Processing Record 42 of Set 10 | tindouf
# Processing Record 43 of Set 10 | mauganj
# Processing Record 44 of Set 10 | aleg
# Processing Record 45 of Set 10 | taksimo
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | ca mau
# Processing Record 48 of Set 10 | susuman
# Processing Record 49 of Set 10 | al khawr
# Processing Record 0 of Set 11 | ayaguz
# City not found. Skipping...
# Processing Record 1 of Set 11 | mulifanua
# City not found. Skipping...
# Processing Record 2 of Set 11 | saipan
# Processing Record 3 of Set 11 | ji parana
# City not found. Skipping...
# Processing Record 4 of Set 11 | floro
# Processing Record 5 of Set 11 | kaseda-shirakame
# Processing Record 6 of Set 11 | mata-utu
# Processing Record 7 of Set 11 | constitucion
# Processing Record 8 of Set 11 | polur
# Processing Record 9 of Set 11 | nova vicosa
# Processing Record 10 of Set 11 | aginskoye
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | bakanas
# Processing Record 13 of Set 11 | freeport
# Processing Record 14 of Set 11 | mahajanga
# Processing Record 15 of Set 11 | kamyaran
# Processing Record 16 of Set 11 | thomson
# Processing Record 17 of Set 11 | duong dong
# Processing Record 18 of Set 11 | andergrove
# Processing Record 19 of Set 11 | puerto santa
# Processing Record 20 of Set 11 | enshi
# Processing Record 21 of Set 11 | chabahar
# Processing Record 22 of Set 11 | miyanoura
# City not found. Skipping...
# Processing Record 23 of Set 11 | wanning
# Processing Record 24 of Set 11 | ancud
# Processing Record 25 of Set 11 | pianiga
# Processing Record 26 of Set 11 | yuzhno-kurilsk
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | muborak
# Processing Record 29 of Set 11 | daru
# Processing Record 30 of Set 11 | beli
# Processing Record 31 of Set 11 | qamdo
# Processing Record 32 of Set 11 | enewetak
# Processing Record 33 of Set 11 | lewistown
# Processing Record 34 of Set 11 | vuktyl
# Processing Record 35 of Set 11 | semey
# Processing Record 36 of Set 11 | nhamunda
# Processing Record 37 of Set 11 | guiria
# City not found. Skipping...
# Processing Record 38 of Set 11 | le port
# Processing Record 39 of Set 11 | cranbrook
# Processing Record 40 of Set 11 | howard springs
# Processing Record 41 of Set 11 | uray
# Processing Record 42 of Set 11 | colonia
# Processing Record 43 of Set 11 | williston
# Processing Record 44 of Set 11 | lodwar
# Processing Record 45 of Set 11 | tabuk
# Processing Record 46 of Set 11 | jampur
# Processing Record 47 of Set 11 | pont rouge
# Processing Record 48 of Set 11 | guiyang
# Processing Record 49 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 0 of Set 12 | aitape
# Processing Record 1 of Set 12 | leh
# Processing Record 2 of Set 12 | nouadhibou
# Processing Record 3 of Set 12 | atasu
# Processing Record 4 of Set 12 | cinisi
# Processing Record 5 of Set 12 | la quiaca
# Processing Record 6 of Set 12 | ambodifotatra
# Processing Record 7 of Set 12 | injambakkam
# City not found. Skipping...
# Processing Record 8 of Set 12 | caconda
# Processing Record 9 of Set 12 | kilinochchi
# Processing Record 10 of Set 12 | lensk
# Processing Record 11 of Set 12 | letlhakane
# Processing Record 12 of Set 12 | kharkhorin
# Processing Record 13 of Set 12 | kazerun
# Processing Record 14 of Set 12 | san juan de los morros
# Processing Record 15 of Set 12 | rukban
# City not found. Skipping...
# Processing Record 16 of Set 12 | san felipe
# Processing Record 17 of Set 12 | urucara
# Processing Record 18 of Set 12 | kristiansund
# Processing Record 19 of Set 12 | qoryooley
# Processing Record 20 of Set 12 | amherst
# Processing Record 21 of Set 12 | vavatenina
# Processing Record 22 of Set 12 | nabire
# Processing Record 23 of Set 12 | balkanabat
# Processing Record 24 of Set 12 | katsuura
# Processing Record 25 of Set 12 | thurso
# Processing Record 26 of Set 12 | gadzhiyevo
# Processing Record 27 of Set 12 | cannonvale
# Processing Record 28 of Set 12 | tlacotepec
# Processing Record 29 of Set 12 | mogocha
# Processing Record 30 of Set 12 | pathein
# Processing Record 31 of Set 12 | tefe
# Processing Record 32 of Set 12 | mponela
# Processing Record 33 of Set 12 | shakawe
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | petrovskaya
# Processing Record 36 of Set 12 | micheweni
# Processing Record 37 of Set 12 | road town
# Processing Record 38 of Set 12 | leticia
# Processing Record 39 of Set 12 | ponta delgada
# Processing Record 40 of Set 12 | shanting
# Processing Record 41 of Set 12 | qaisumah
# Processing Record 42 of Set 12 | karoi
# Processing Record 43 of Set 12 | caleta de carquin
# Processing Record 44 of Set 12 | wynyard
# Processing Record 45 of Set 12 | bayan
# Processing Record 46 of Set 12 | mo i rana
# Processing Record 47 of Set 12 | midvagur
# Processing Record 48 of Set 12 | valday
# Processing Record 49 of Set 12 | warman
# Processing Record 0 of Set 13 | chui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   klyuchi  52.2667   79.1667     17.24        28          22        3.78
# 1    anadyr  64.7500  177.4833      3.28        93          40        2.00
# 2    yantai  37.5333  121.4000     21.85        71          96        3.65
# 3  luderitz -26.6481   15.1594     25.14        31           0        4.36
# 4   hatillo  18.4863  -66.8254     27.27        93          24        1.34
#
#   Country        Date
# 0      RU  1695808143
# 1      RU  1695808143
# 2      CN  1695808143
# 3      NA  1695808132
# 4      PR  1695808143

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         klyuchi  52.2667   79.1667     17.24        28          22
# 1          anadyr  64.7500  177.4833      3.28        93          40
# 2          yantai  37.5333  121.4000     21.85        71          96
# 3        luderitz -26.6481   15.1594     25.14        31           0
# 4         hatillo  18.4863  -66.8254     27.27        93          24
#
#          Wind Speed Country        Date
# City_ID
# 0              3.78      RU  1695808143
# 1              2.00      RU  1695808143
# 2              3.65      CN  1695808143
# 3              4.36     NaN  1695808132
# 4              1.34      PR  1695808143

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (°C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_linear_regression_plot(x_values, y_values, xlabel, ylabel, title, annotate_position):
    """
    Create a scatter plot with linear regression for the given x and y values.
    
    Parameters:
    - x_values, y_values: Data for scatter plot.
    - xlabel, ylabel, title: Labels for the plot.
    - annotate_position: Tuple indicating position for the linear regression equation on the plot.
    """
    
    # Calculate linear regression
    (slope, intercept, rvalue, _, _) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(line_eq, annotate_position, fontsize=15, color="red")
    plt.grid(True)
    plt.show()

    # Output the r-value
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          klyuchi  52.2667   79.1667     17.24        28          22
# 1           anadyr  64.7500  177.4833      3.28        93          40
# 2           yantai  37.5333  121.4000     21.85        71          96
# 4          hatillo  18.4863  -66.8254     27.27        93          24
# 5        jamestown  42.0970  -79.2353     13.73        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.78      RU  1695808143
# 1              2.00      RU  1695808143
# 2              3.65      CN  1695808143
# 4              1.34      PR  1695808143
# 5              4.12      US  1695808144

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                 luderitz -26.6481   15.1594     25.14        31           0
# 10                    ende  -8.8432  121.6623     25.74        73          95
# 12              bredasdorp -34.5322   20.0403     18.00        57           1
# 15       port-aux-francais -49.3500   70.2167      0.98        69          87
# 21          margaret river -33.9500  115.0667     19.32        72           0
#
#          Wind Speed Country        Date
# City_ID
# 3              4.36     NaN  1695808132
# 10             2.04      ID  1695808144
# 12             5.07      ZA  1695808144
# 15            15.92      TF  1695808145
# 21             2.14      AU  1695808145

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
create_linear_regression_plot(x_values, y_values, 
                                     xlabel='Latitude', 
                                     ylabel='Max Temperature (°C)', 
                                     title='Northern Hemisphere (Max Temp vs. Latitude Linear Regression)', 
                                     annotate_position=(10, 3))
# Out:
# The r-value is: -0.7750867529027119

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

create_linear_regression_plot(x_values, y_values, 
                             xlabel='Latitude', 
                             ylabel='Max Temperature (°C)', 
                             title='Southern Hemisphere (Max Temp vs. Latitude Linear Regression)', 
                             annotate_position=(-53,30))
# Out:
# The r-value is: 0.7519748653146927

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The relationship between temperature and latitude in the Northern hemisphere is such that an increase in the latitude results in a decrease in the temperature. Thus, showing a fairly strong inverse correlation. This is also reflected in the negative r-value obtained.
#
# In the Southern hemispher, however, an increase in the latitude results in an increase in the temperature. This shows a very strong positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Humidity (%)', 
                                   title='Northern Hemisphere (Humidity vs. Latitude Linear Regression)', 
                                   annotate_position=(45, 20))
# Out:
# The r-value is: 0.0369267937800593

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Humidity (%)', 
                                   title='Southern Hemisphere (Humidity vs. Latitude Linear Regression)', 
                                   annotate_position=(-50, 20))
# Out:
# The r-value is: -0.064830253958544

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The relationship between latitude and humidity in the Northern hemisphere is such that an increase in the latitude results in a slight trend indicating the likelihood of an increase in humidity. Thus, suggesting a weak positive correlation between humidity and latitude. This is evident in an r-value of 0.0369267937800593.
#
# In the Southern hemisphere, the negative r-value suggests weak negative relationship between latitude and humidity.As latitude increases, there's a slight trend indicating the likelihood of a decrease in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Cloudiness (%)', 
                                   title='Northern Hemisphere (Cloudiness vs. Latitude Linear Regression)', 
                                   annotate_position=(40, 15))
# Out:
# The r-value is: 0.1496971135611324

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Cloudiness (%)', 
                                   title='Southern Hemisphere (Cloudiness vs. Latitude Linear Regression)', 
                                   annotate_position=(-50, 20))
# Out:
# The r-value is: -0.028188480933351835

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the northern hemisphere, there is a weak positive correlation between latitude and cloudiness. As latitude increases, there's a slight trend indicating an increase in cloudiness. However, as the r-value id close to zero, it suggest that the correlation is minimal. Hence, latitude may not be the key determinant of cloudiness in the northern hemisphere.
#
# The Southern hemisphere shows an even weaker correlation between cloudiness and latitude. Even so, it is observed that maximum cloudiness was experienced across all the latitudes.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Wind Speed (m/s)', 
                                   title='Northern Hemisphere (Wind Speed vs. Latitude Linear Regression)', 
                                   annotate_position=(40, 9))
# Out:
# The r-value is: 0.051678164458835954

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
create_linear_regression_plot(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Wind Speed (m/s)', 
                                   title='Southern Hemisphere (Wind Speed vs. Latitude Linear Regression)', 
                                   annotate_position=(-30, 12))
# Out:
# The r-value is: -0.17230263133802678

# %% [markdown]
# **Discussion about the linear relationship:**
#
# As latitude increases in the Northern hemisphere, there's a very slight trend indicating a increase in wind speed observed. This suggests a  weak positive relationship between wind speed and latitiude. It suggests that while latitude might have some effect on wind speed in the Northern hemisphere, it's not the predominant factor.
#
# As latitude increases in the Southern hemisphere, there's a trend suggesting a decrease in wind speed observed. This suggests a weak negative correlation between wind speed and latitude. While this correlation is still weak, it's slightly stronger than in the Northern Hemisphere, indicating a more pronounced (yet subtle) effect of latitude on wind speed in the Southern Hemisphere.
