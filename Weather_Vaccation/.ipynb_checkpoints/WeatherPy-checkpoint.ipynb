# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | fale old settlement
# Processing Record 3 of Set 1 | stanley
# Processing Record 4 of Set 1 | edinburgh of the seven seas
# Processing Record 5 of Set 1 | margaret river
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | invercargill
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | skiatook
# Processing Record 13 of Set 1 | olonkinbyen
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | glencoe
# Processing Record 16 of Set 1 | nuuk
# Processing Record 17 of Set 1 | pangoa
# Processing Record 18 of Set 1 | vorgashor
# Processing Record 19 of Set 1 | shimoda
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | hakha
# Processing Record 22 of Set 1 | playa del ingles
# Processing Record 23 of Set 1 | shihezi
# Processing Record 24 of Set 1 | fuyang
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | thasra
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 1 | paramonga
# Processing Record 31 of Set 1 | ghadamis
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | mejit
# Processing Record 34 of Set 1 | dryden
# Processing Record 35 of Set 1 | toliara
# Processing Record 36 of Set 1 | adamstown
# Processing Record 37 of Set 1 | waitangi
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | uturoa
# Processing Record 40 of Set 1 | 'alaqahdari dishu
# Processing Record 41 of Set 1 | mabaruma
# Processing Record 42 of Set 1 | purpe
# Processing Record 43 of Set 1 | santo antonio
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | labrador city
# Processing Record 46 of Set 1 | west island
# Processing Record 47 of Set 1 | afaahiti
# Processing Record 48 of Set 1 | santarem
# Processing Record 49 of Set 1 | ravar
# Processing Record 50 of Set 1 | papatowai
# Processing Record 0 of Set 2 | taguatinga
# Processing Record 1 of Set 2 | ust'-barguzin
# Processing Record 2 of Set 2 | san julian
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | demba
# Processing Record 5 of Set 2 | namtsy
# Processing Record 6 of Set 2 | juegang
# Processing Record 7 of Set 2 | acarau
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | dzuunharaa
# Processing Record 11 of Set 2 | minas de marcona
# Processing Record 12 of Set 2 | badger
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | lockwood
# Processing Record 15 of Set 2 | redencao
# Processing Record 16 of Set 2 | blackmans bay
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | isafjordur
# Processing Record 19 of Set 2 | flying fish cove
# Processing Record 20 of Set 2 | st. john's
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 24 of Set 2 | mtsensk
# Processing Record 25 of Set 2 | puerto san jose
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | langtoucun
# Processing Record 28 of Set 2 | keflavik
# Processing Record 29 of Set 2 | salinopolis
# Processing Record 30 of Set 2 | nar'yan-mar
# Processing Record 31 of Set 2 | kailua-kona
# Processing Record 32 of Set 2 | saryozek
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | puerto natales
# Processing Record 35 of Set 2 | woodland
# Processing Record 36 of Set 2 | susuman
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | medyn'
# Processing Record 39 of Set 2 | wynyard
# Processing Record 40 of Set 2 | planaltina
# Processing Record 41 of Set 2 | oltinko'l
# Processing Record 42 of Set 2 | argo
# Processing Record 43 of Set 2 | chonchi
# Processing Record 44 of Set 2 | rio grande
# Processing Record 45 of Set 2 | weno
# Processing Record 46 of Set 2 | rundu
# Processing Record 47 of Set 2 | agat village
# Processing Record 48 of Set 2 | hawaiian paradise park
# Processing Record 49 of Set 2 | mana
# Processing Record 0 of Set 3 | balkanabat
# Processing Record 1 of Set 3 | cold lake
# Processing Record 2 of Set 3 | bubaque
# Processing Record 3 of Set 3 | suining
# Processing Record 4 of Set 3 | queenstown
# Processing Record 5 of Set 3 | santa cruz
# Processing Record 6 of Set 3 | xinqing
# Processing Record 7 of Set 3 | santa isabel
# Processing Record 8 of Set 3 | karratha
# Processing Record 9 of Set 3 | ust-nera
# Processing Record 10 of Set 3 | port clinton
# Processing Record 11 of Set 3 | grand falls-windsor
# Processing Record 12 of Set 3 | udachny
# Processing Record 13 of Set 3 | al jawf
# Processing Record 14 of Set 3 | sitia
# Processing Record 15 of Set 3 | krasnoshchekovo
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | iskateley
# Processing Record 18 of Set 3 | mogocha
# Processing Record 19 of Set 3 | geneina
# Processing Record 20 of Set 3 | kapa'a
# Processing Record 21 of Set 3 | okha
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | penne
# Processing Record 25 of Set 3 | greenfields
# Processing Record 26 of Set 3 | arkhangel'sk
# Processing Record 27 of Set 3 | birobidzhan
# Processing Record 28 of Set 3 | wuhu
# Processing Record 29 of Set 3 | taltal
# Processing Record 30 of Set 3 | ghanzi
# Processing Record 31 of Set 3 | qaqortoq
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | kilindoni
# Processing Record 34 of Set 3 | omuthiya
# City not found. Skipping...
# Processing Record 35 of Set 3 | nago
# Processing Record 36 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 37 of Set 3 | gola gokarannath
# Processing Record 38 of Set 3 | villa regina
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | coahuayana de hidalgo
# Processing Record 41 of Set 3 | whangarei
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | horta
# Processing Record 44 of Set 3 | malango
# Processing Record 45 of Set 3 | enewetak
# Processing Record 46 of Set 3 | albion
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | kingston
# Processing Record 0 of Set 4 | galle
# Processing Record 1 of Set 4 | princeville
# Processing Record 2 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 3 of Set 4 | yuzhno-kurilsk
# Processing Record 4 of Set 4 | atyashevo
# Processing Record 5 of Set 4 | susanville
# Processing Record 6 of Set 4 | jiagedaqi
# Processing Record 7 of Set 4 | chui
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | moree
# Processing Record 10 of Set 4 | vega de alatorre
# Processing Record 11 of Set 4 | gorontalo
# Processing Record 12 of Set 4 | mili
# Processing Record 13 of Set 4 | kourou
# Processing Record 14 of Set 4 | gadzhiyevo
# Processing Record 15 of Set 4 | abepura
# Processing Record 16 of Set 4 | aasiaat
# Processing Record 17 of Set 4 | nemuro
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | tanjung selor
# City not found. Skipping...
# Processing Record 20 of Set 4 | tianpeng
# Processing Record 21 of Set 4 | bizhbulyak
# Processing Record 22 of Set 4 | anadyr
# Processing Record 23 of Set 4 | merizo village
# Processing Record 24 of Set 4 | rongelap
# Processing Record 25 of Set 4 | trzebiatow
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | onega
# Processing Record 28 of Set 4 | klyuchi
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | jalai nur
# Processing Record 31 of Set 4 | barah
# Processing Record 32 of Set 4 | pedernales
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | cody
# Processing Record 35 of Set 4 | gilgit
# Processing Record 36 of Set 4 | raja
# Processing Record 37 of Set 4 | nova sintra
# Processing Record 38 of Set 4 | lengshuijiang
# Processing Record 39 of Set 4 | pangody
# Processing Record 40 of Set 4 | spanish wells
# Processing Record 41 of Set 4 | sungai penuh
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | sarina
# Processing Record 44 of Set 4 | louisville
# Processing Record 45 of Set 4 | praia da vitoria
# Processing Record 46 of Set 4 | sai buri
# Processing Record 47 of Set 4 | taulaga
# Processing Record 48 of Set 4 | aitape
# Processing Record 49 of Set 4 | luderitz
# Processing Record 0 of Set 5 | lorengau
# Processing Record 1 of Set 5 | al-hamdaniya
# Processing Record 2 of Set 5 | jinchang
# Processing Record 3 of Set 5 | fengcheng
# Processing Record 4 of Set 5 | gros islet
# Processing Record 5 of Set 5 | nadym
# Processing Record 6 of Set 5 | walvis bay
# Processing Record 7 of Set 5 | grajau
# Processing Record 8 of Set 5 | kiruhura
# Processing Record 9 of Set 5 | nizhnevartovsk
# Processing Record 10 of Set 5 | tachov
# Processing Record 11 of Set 5 | tandalti
# Processing Record 12 of Set 5 | hirara
# Processing Record 13 of Set 5 | kurchatov
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | las lomitas
# Processing Record 16 of Set 5 | marudi
# City not found. Skipping...
# Processing Record 17 of Set 5 | massakory
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | palmer
# Processing Record 20 of Set 5 | lethem
# Processing Record 21 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 5 | sealy
# Processing Record 23 of Set 5 | khovd
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | christchurch
# Processing Record 27 of Set 5 | sinegorskiy
# Processing Record 28 of Set 5 | cromer
# Processing Record 29 of Set 5 | sao miguel do araguaia
# Processing Record 30 of Set 5 | kapuskasing
# Processing Record 31 of Set 5 | sao felix do xingu
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | vilyuchinsk
# Processing Record 34 of Set 5 | tharangambadi
# Processing Record 35 of Set 5 | general conesa
# Processing Record 36 of Set 5 | lasem
# Processing Record 37 of Set 5 | luganville
# Processing Record 38 of Set 5 | rabo de peixe
# Processing Record 39 of Set 5 | sao lourenco do sul
# Processing Record 40 of Set 5 | falam
# Processing Record 41 of Set 5 | tandil
# Processing Record 42 of Set 5 | port mathurin
# Processing Record 43 of Set 5 | aykhal
# Processing Record 44 of Set 5 | homer
# Processing Record 45 of Set 5 | vila franca do campo
# Processing Record 46 of Set 5 | iquique
# Processing Record 47 of Set 5 | pacific grove
# Processing Record 48 of Set 5 | amvrosiyivka
# Processing Record 49 of Set 5 | utrik
# Processing Record 0 of Set 6 | vadso
# Processing Record 1 of Set 6 | mar del plata
# Processing Record 2 of Set 6 | tubarjal
# Processing Record 3 of Set 6 | whitehorse
# Processing Record 4 of Set 6 | lihue
# Processing Record 5 of Set 6 | kirakira
# Processing Record 6 of Set 6 | suixi
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | mount isa
# Processing Record 9 of Set 6 | happy valley-goose bay
# Processing Record 10 of Set 6 | sinabang
# Processing Record 11 of Set 6 | tofol
# Processing Record 12 of Set 6 | chiili
# City not found. Skipping...
# Processing Record 13 of Set 6 | genhe
# Processing Record 14 of Set 6 | essaouira
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | parabel'
# Processing Record 17 of Set 6 | tromso
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | selfoss
# Processing Record 20 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 6 | souillac
# Processing Record 22 of Set 6 | gaspe
# Processing Record 23 of Set 6 | bethanie
# Processing Record 24 of Set 6 | yerofey pavlovich
# Processing Record 25 of Set 6 | hadibu
# Processing Record 26 of Set 6 | kogalym
# Processing Record 27 of Set 6 | halifax
# Processing Record 28 of Set 6 | tateyama
# Processing Record 29 of Set 6 | hinna
# Processing Record 30 of Set 6 | severobaykal'sk
# Processing Record 31 of Set 6 | makarov
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | fuglafjordur
# Processing Record 34 of Set 6 | funafuti
# Processing Record 35 of Set 6 | alvaraes
# Processing Record 36 of Set 6 | brandon
# Processing Record 37 of Set 6 | haiku-pauwela
# Processing Record 38 of Set 6 | hamilton
# Processing Record 39 of Set 6 | manavalakurichi
# Processing Record 40 of Set 6 | north bend
# Processing Record 41 of Set 6 | hazard
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | la'ie
# Processing Record 44 of Set 6 | crane
# Processing Record 45 of Set 6 | vilhena
# Processing Record 46 of Set 6 | tazovsky
# Processing Record 47 of Set 6 | aral
# Processing Record 48 of Set 6 | holualoa
# Processing Record 49 of Set 6 | kondopoga
# Processing Record 0 of Set 7 | nogliki
# Processing Record 1 of Set 7 | astrakhan
# Processing Record 2 of Set 7 | ulladulla
# Processing Record 3 of Set 7 | xichang
# Processing Record 4 of Set 7 | willowmore
# Processing Record 5 of Set 7 | seogwipo
# City not found. Skipping...
# Processing Record 6 of Set 7 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 7 of Set 7 | wenchang
# Processing Record 8 of Set 7 | otsuchi
# Processing Record 9 of Set 7 | bowling green
# Processing Record 10 of Set 7 | hastings
# Processing Record 11 of Set 7 | afif
# Processing Record 12 of Set 7 | khandyga
# Processing Record 13 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 14 of Set 7 | hammerfest
# Processing Record 15 of Set 7 | zhangye
# Processing Record 16 of Set 7 | spring creek
# Processing Record 17 of Set 7 | basco
# Processing Record 18 of Set 7 | new glasgow
# Processing Record 19 of Set 7 | daru
# Processing Record 20 of Set 7 | tamanrasset
# Processing Record 21 of Set 7 | uyar
# Processing Record 22 of Set 7 | atafu village
# Processing Record 23 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 24 of Set 7 | kone
# Processing Record 25 of Set 7 | galliano
# Processing Record 26 of Set 7 | ninotsminda
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | kasama
# Processing Record 29 of Set 7 | howrah
# Processing Record 30 of Set 7 | tocopilla
# Processing Record 31 of Set 7 | mossel bay
# Processing Record 32 of Set 7 | kalabo
# Processing Record 33 of Set 7 | sepolno krajenskie
# Processing Record 34 of Set 7 | jutai
# Processing Record 35 of Set 7 | east london
# Processing Record 36 of Set 7 | carauari
# Processing Record 37 of Set 7 | manta
# Processing Record 38 of Set 7 | vernouillet
# Processing Record 39 of Set 7 | codrington
# Processing Record 40 of Set 7 | tinyahuarco
# Processing Record 41 of Set 7 | puerto baquerizo moreno
# Processing Record 42 of Set 7 | nova vicosa
# Processing Record 43 of Set 7 | komsomol'skiy
# Processing Record 44 of Set 7 | adam
# Processing Record 45 of Set 7 | conception bay south
# Processing Record 46 of Set 7 | zhenzhou
# Processing Record 47 of Set 7 | dunedin
# Processing Record 48 of Set 7 | tazacorte
# Processing Record 49 of Set 7 | palasa
# Processing Record 0 of Set 8 | hotan
# Processing Record 1 of Set 8 | oriximina
# Processing Record 2 of Set 8 | nanzhang chengguanzhen
# Processing Record 3 of Set 8 | jayapura
# Processing Record 4 of Set 8 | antofagasta
# Processing Record 5 of Set 8 | jabat
# Processing Record 6 of Set 8 | nanma
# Processing Record 7 of Set 8 | telaga batu
# City not found. Skipping...
# Processing Record 8 of Set 8 | sinop
# Processing Record 9 of Set 8 | dudinka
# Processing Record 10 of Set 8 | kwolla
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | celestun
# Processing Record 13 of Set 8 | tralee
# Processing Record 14 of Set 8 | teguise
# Processing Record 15 of Set 8 | san luis de la loma
# Processing Record 16 of Set 8 | nahrin
# Processing Record 17 of Set 8 | jeremoabo
# Processing Record 18 of Set 8 | stonehaven
# Processing Record 19 of Set 8 | fernie
# Processing Record 20 of Set 8 | rach gia
# Processing Record 21 of Set 8 | muisne
# Processing Record 22 of Set 8 | rio preto da eva
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | rockville
# Processing Record 25 of Set 8 | kabansk
# Processing Record 26 of Set 8 | shakhun'ya
# Processing Record 27 of Set 8 | dul'durga
# Processing Record 28 of Set 8 | ijui
# Processing Record 29 of Set 8 | cangas del narcea
# Processing Record 30 of Set 8 | chibougamau
# Processing Record 31 of Set 8 | greymouth
# Processing Record 32 of Set 8 | pingnan
# Processing Record 33 of Set 8 | bayganin
# Processing Record 34 of Set 8 | howard springs
# Processing Record 35 of Set 8 | paita
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | labasa
# Processing Record 38 of Set 8 | elkins
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | guli
# Processing Record 41 of Set 8 | n'zeto
# Processing Record 42 of Set 8 | tanjungtiram
# Processing Record 43 of Set 8 | saudarkrokur
# Processing Record 44 of Set 8 | iowa park
# Processing Record 45 of Set 8 | debre werk'
# Processing Record 46 of Set 8 | farkhar
# Processing Record 47 of Set 8 | fonadhoo
# City not found. Skipping...
# Processing Record 48 of Set 8 | fairmont
# Processing Record 49 of Set 8 | alice springs
# Processing Record 0 of Set 9 | coquimbo
# Processing Record 1 of Set 9 | vallenar
# Processing Record 2 of Set 9 | bilokurakyne
# Processing Record 3 of Set 9 | yonggwang-up
# Processing Record 4 of Set 9 | ketchikan
# Processing Record 5 of Set 9 | alamosa
# Processing Record 6 of Set 9 | qarqaraly
# Processing Record 7 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 8 of Set 9 | port lincoln
# Processing Record 9 of Set 9 | mermoz boabab
# Processing Record 10 of Set 9 | rikaze
# Processing Record 11 of Set 9 | langhirano
# Processing Record 12 of Set 9 | brokopondo
# Processing Record 13 of Set 9 | al ghayzah
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | ilhabela
# Processing Record 16 of Set 9 | kotabumi
# Processing Record 17 of Set 9 | fuli
# Processing Record 18 of Set 9 | zambezi
# Processing Record 19 of Set 9 | hobyo
# Processing Record 20 of Set 9 | porto torres
# Processing Record 21 of Set 9 | suva
# Processing Record 22 of Set 9 | puerto madero
# Processing Record 23 of Set 9 | bel ombre
# Processing Record 24 of Set 9 | reggane
# Processing Record 25 of Set 9 | brookings
# Processing Record 26 of Set 9 | ambarakaraka
# City not found. Skipping...
# Processing Record 27 of Set 9 | bardai
# Processing Record 28 of Set 9 | gwio kura
# Processing Record 29 of Set 9 | la serena
# Processing Record 30 of Set 9 | saint-henri
# Processing Record 31 of Set 9 | zapala
# Processing Record 32 of Set 9 | launceston
# Processing Record 33 of Set 9 | kangding
# Processing Record 34 of Set 9 | trincomalee
# Processing Record 35 of Set 9 | smara
# Processing Record 36 of Set 9 | san luis jilotepeque
# Processing Record 37 of Set 9 | constantia
# Processing Record 38 of Set 9 | kismayo
# Processing Record 39 of Set 9 | kapenguria
# Processing Record 40 of Set 9 | thinadhoo
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | gohpur
# Processing Record 43 of Set 9 | kiziltepe
# Processing Record 44 of Set 9 | kuzhener
# Processing Record 45 of Set 9 | mae hong son
# Processing Record 46 of Set 9 | usogorsk
# Processing Record 47 of Set 9 | ouro sogui
# Processing Record 48 of Set 9 | malayer
# Processing Record 49 of Set 9 | cordoba
# Processing Record 0 of Set 10 | takoradi
# Processing Record 1 of Set 10 | lakatoro
# Processing Record 2 of Set 10 | saldanha
# Processing Record 3 of Set 10 | vilyuysk
# Processing Record 4 of Set 10 | zhaobaoshan
# Processing Record 5 of Set 10 | quatre cocos
# Processing Record 6 of Set 10 | heroica caborca
# Processing Record 7 of Set 10 | markovo
# Processing Record 8 of Set 10 | oued zem
# Processing Record 9 of Set 10 | farasan
# Processing Record 10 of Set 10 | morondava
# Processing Record 11 of Set 10 | luwuk
# Processing Record 12 of Set 10 | amalapuram
# Processing Record 13 of Set 10 | la ronge
# Processing Record 14 of Set 10 | caleta de carquin
# Processing Record 15 of Set 10 | villa gonzalez ortega
# Processing Record 16 of Set 10 | rio tuba
# Processing Record 17 of Set 10 | vakfikebir
# Processing Record 18 of Set 10 | bumba
# Processing Record 19 of Set 10 | gizo
# Processing Record 20 of Set 10 | sao jose da coroa grande
# Processing Record 21 of Set 10 | alesund
# Processing Record 22 of Set 10 | egilsstadir
# Processing Record 23 of Set 10 | chandbali
# Processing Record 24 of Set 10 | callao
# Processing Record 25 of Set 10 | whyalla stuart
# City not found. Skipping...
# Processing Record 26 of Set 10 | batar
# Processing Record 27 of Set 10 | irtyshsk
# Processing Record 28 of Set 10 | sabang
# Processing Record 29 of Set 10 | yuyao
# Processing Record 30 of Set 10 | acapulco de juarez
# Processing Record 31 of Set 10 | shingu
# Processing Record 32 of Set 10 | kvissleby
# Processing Record 33 of Set 10 | willis
# Processing Record 34 of Set 10 | warmbad
# Processing Record 35 of Set 10 | al artawiyah
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | katabu
# Processing Record 38 of Set 10 | lamu
# Processing Record 39 of Set 10 | troitsko-pechorsk
# Processing Record 40 of Set 10 | ostersund
# Processing Record 41 of Set 10 | malanje
# Processing Record 42 of Set 10 | athens
# Processing Record 43 of Set 10 | bousso
# Processing Record 44 of Set 10 | xilin hot
# Processing Record 45 of Set 10 | savnik
# City not found. Skipping...
# Processing Record 46 of Set 10 | larkird
# Processing Record 47 of Set 10 | parnu
# Processing Record 48 of Set 10 | mount gambier
# Processing Record 49 of Set 10 | ulanhot
# Processing Record 0 of Set 11 | birine
# Processing Record 1 of Set 11 | vernon
# Processing Record 2 of Set 11 | cockburn town
# Processing Record 3 of Set 11 | muswellbrook
# Processing Record 4 of Set 11 | bloomingdale
# Processing Record 5 of Set 11 | sao gabriel
# Processing Record 6 of Set 11 | cadale
# Processing Record 7 of Set 11 | vorkuta
# Processing Record 8 of Set 11 | ambatofinandrahana
# Processing Record 9 of Set 11 | amga
# Processing Record 10 of Set 11 | lincheng
# Processing Record 11 of Set 11 | sisimiut
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | juli
# Processing Record 14 of Set 11 | okhotsk
# Processing Record 15 of Set 11 | formosa
# Processing Record 16 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 11 | challakere
# Processing Record 18 of Set 11 | malvan
# Processing Record 19 of Set 11 | popondetta
# Processing Record 20 of Set 11 | dukhan
# Processing Record 21 of Set 11 | sena madureira
# Processing Record 22 of Set 11 | masina
# Processing Record 23 of Set 11 | toktogul
# Processing Record 24 of Set 11 | cesvaine
# Processing Record 25 of Set 11 | danville
# Processing Record 26 of Set 11 | yichun
# Processing Record 27 of Set 11 | inga
# Processing Record 28 of Set 11 | saint-denis
# Processing Record 29 of Set 11 | coruripe
# Processing Record 30 of Set 11 | moreira sales
# Processing Record 31 of Set 11 | el tigre
# Processing Record 32 of Set 11 | puerto deseado
# Processing Record 33 of Set 11 | itoman
# Processing Record 34 of Set 11 | sagua de tanamo
# Processing Record 35 of Set 11 | atchison
# Processing Record 36 of Set 11 | jangipur
# Processing Record 37 of Set 11 | isetskoye
# Processing Record 38 of Set 11 | mukalla
# Processing Record 39 of Set 11 | guadalupe y calvo
# Processing Record 40 of Set 11 | i-n-salah
# Processing Record 41 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 42 of Set 11 | balakhta
# Processing Record 43 of Set 11 | wellington
# Processing Record 44 of Set 11 | kayangel
# Processing Record 45 of Set 11 | nanchong
# Processing Record 46 of Set 11 | qamdo
# Processing Record 47 of Set 11 | saipan
# Processing Record 48 of Set 11 | erenhot
# Processing Record 49 of Set 11 | castillos
# Processing Record 0 of Set 12 | rantauprapat
# Processing Record 1 of Set 12 | kolonia
# Processing Record 2 of Set 12 | magadan
# Processing Record 3 of Set 12 | opuwo
# Processing Record 4 of Set 12 | condoto
# Processing Record 5 of Set 12 | colon
# Processing Record 6 of Set 12 | port augusta
# Processing Record 7 of Set 12 | maintirano
# Processing Record 8 of Set 12 | traralgon
# Processing Record 9 of Set 12 | punta del este
# Processing Record 10 of Set 12 | buritizeiro
# Processing Record 11 of Set 12 | grand-bassam
# Processing Record 12 of Set 12 | tobi village
# City not found. Skipping...
# Processing Record 13 of Set 12 | bushland beach
# City not found. Skipping...
# Processing Record 14 of Set 12 | nova londrina
# Processing Record 15 of Set 12 | shiraz
# Processing Record 16 of Set 12 | zhuanghe
# Processing Record 17 of Set 12 | colonia
# Processing Record 18 of Set 12 | aktau
# Processing Record 19 of Set 12 | san felipe jalapa de diaz
# Processing Record 20 of Set 12 | bac kan
# Processing Record 21 of Set 12 | ueckermunde
# Processing Record 22 of Set 12 | peterhead
# Processing Record 23 of Set 12 | svetlyy
# Processing Record 24 of Set 12 | guerrero negro
# Processing Record 25 of Set 12 | chernomorskoye
# Processing Record 26 of Set 12 | labuan
# Processing Record 27 of Set 12 | san andros
# City not found. Skipping...
# Processing Record 28 of Set 12 | nebbi
# Processing Record 29 of Set 12 | juan griego
# Processing Record 30 of Set 12 | paciran
# Processing Record 31 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 12 | mukah
# City not found. Skipping...
# Processing Record 33 of Set 12 | boyolangu
# Processing Record 34 of Set 12 | rothenburg ob der tauber
# Processing Record 35 of Set 12 | tostado
# Processing Record 36 of Set 12 | masterton
# Processing Record 37 of Set 12 | kirensk
# Processing Record 38 of Set 12 | stiens
# Processing Record 39 of Set 12 | florence
# Processing Record 40 of Set 12 | remire-montjoly
# Processing Record 41 of Set 12 | island harbour
# Processing Record 42 of Set 12 | buriti bravo
# Processing Record 43 of Set 12 | kasane
# Processing Record 44 of Set 12 | augusto correa
# Processing Record 45 of Set 12 | puerto armuelles
# Processing Record 46 of Set 12 | port shepstone
# Processing Record 47 of Set 12 | sikonge
# Processing Record 48 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 49 of Set 12 | gwadar
# Processing Record 0 of Set 13 | sola
# Processing Record 1 of Set 13 | ouellah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                    grytviken -54.2811  -36.5092     -2.28        94
# 1          fale old settlement  -9.3852 -171.2468     27.86        75
# 2                      stanley  54.8680   -1.6985     20.44        90
# 3  edinburgh of the seven seas -37.0676  -12.3116      9.70        57
# 4               margaret river -33.9500  115.0667     14.73        68
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        0.92      GS  1694294767
# 1          68        3.22      TK  1694294767
# 2          20        2.06      GB  1694294767
# 3          88       12.16      SH  1694294768
# 4         100        4.96      AU  1694294768

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          grytviken -54.2811  -36.5092     -2.28        94
# 1                fale old settlement  -9.3852 -171.2468     27.86        75
# 2                            stanley  54.8680   -1.6985     20.44        90
# 3        edinburgh of the seven seas -37.0676  -12.3116      9.70        57
# 4                     margaret river -33.9500  115.0667     14.73        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        0.92      GS  1694294767
# 1                68        3.22      TK  1694294767
# 2                20        2.06      GB  1694294767
# 3                88       12.16      SH  1694294768
# 4               100        4.96      AU  1694294768

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (°C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_linear_regression_plot(x_values, y_values, xlabel, ylabel, title, annotate_position):
    """
    Create a scatter plot with linear regression for the given x and y values.
    
    Parameters:
    - x_values, y_values: Data for scatter plot.
    - xlabel, ylabel, title: Labels for the plot.
    - annotate_position: Tuple indicating position for the linear regression equation on the plot.
    """
    
    # Calculate linear regression
    (slope, intercept, rvalue, _, _) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(line_eq, annotate_position, fontsize=15, color="red")
    plt.grid(True)
    plt.show()

    # Output the r-value
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               stanley  54.8680  -1.6985     20.44        90          20
# 5               iqaluit  63.7506 -68.5145      5.85        70          20
# 7        ribeira grande  38.5167 -28.7000     22.22        73          75
# 9             jamestown  42.0970 -79.2353     20.01        91         100
# 10               albany  42.6001 -73.9662     26.44        75         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.06      GB  1694294767
# 5              4.12      CA  1694294768
# 7              3.13      PT  1694294768
# 9              0.45      US  1694294768
# 10             0.45      US  1694294768

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          grytviken -54.2811  -36.5092     -2.28        94
# 1                fale old settlement  -9.3852 -171.2468     27.86        75
# 3        edinburgh of the seven seas -37.0676  -12.3116      9.70        57
# 4                     margaret river -33.9500  115.0667     14.73        68
# 6                       invercargill -46.4000  168.3500     10.57        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        0.92      GS  1694294767
# 1                68        3.22      TK  1694294767
# 3                88       12.16      SH  1694294768
# 4               100        4.96      AU  1694294768
# 6                99        1.34      NZ  1694294768

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
create_linear_regression_plot(x_values, y_values, 
                                     xlabel='Latitude', 
                                     ylabel='Max Temperature (°C)', 
                                     title='Northern Hemisphere (Max Temp vs. Latitude Linear Regression)', 
                                     annotate_position=(10, 3))
# Out:
# The r-value is: -0.727624316994474

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

create_linear_regression_plot(x_values, y_values, 
                             xlabel='Latitude', 
                             ylabel='Max Temperature (°C)', 
                             title='Southern Hemisphere (Max Temp vs. Latitude Linear Regression)', 
                             annotate_position=(-53,30))
# Out:
# The r-value is: 0.7652433467911062

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The relationship between temperature and latitude in the Northern hemisphere is such that an increase in the latitude results in a decrease in the temperature. Thus, showing a fairly strong inverse correlation. This is also reflected in the negative r-value obtained.
#
# In the Southern hemispher, however, an increase in the latitude results in an increase in the temperature. This shows a very strong positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Humidity (%)', 
                                   title='Northern Hemisphere (Humidity vs. Latitude Linear Regression)', 
                                   annotate_position=(45, 20))
# Out:
# The r-value is: 0.045365895306276

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Humidity (%)', 
                                   title='Southern Hemisphere (Humidity vs. Latitude Linear Regression)', 
                                   annotate_position=(-50, 3))
# Out:
# The r-value is: -0.027978332157281332

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The relationship between latitude and humidity in the Northern hemisphere is such that an increase in the latitude results in a slight trend indicating the likelihood of an increase in humidity. Thus, suggesting a weak positive correlation between humidity and latitude. This is evident in an r-value of 0.045365895306276.
#
# In the Southern hemisphere, the negative r-value suggests very weak negative relationship between latitude and humidity.As latitude increases, there's a slight trend indicating the likelihood of a decrease in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Cloudiness (%)', 
                                   title='Northern Hemisphere (Cloudiness vs. Latitude Linear Regression)', 
                                   annotate_position=(40, 15))
# Out:
# The r-value is: 0.027573979159976853

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Cloudiness (%)', 
                                   title='Southern Hemisphere (Cloudiness vs. Latitude Linear Regression)', 
                                   annotate_position=(-50, 20))
# Out:
# The r-value is: 0.07046615377326386

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In the northern hemisphere, there is a very weak positive correlation between latitude and cloudiness. As latitude increases, there's a slight trend indicating an increase in cloudiness. However, as the r-value id close to zero, it suggest that the correlation is minimal. Hence, latitude may not be the key detrminant of cloudiness in the northern hemisphere.
#
# In the Southern hemisphere, the correlation is very weak but slightly stronger correlation than the northen hemisphere. It implies that as latitude increases, the cloudiness increases. In the Southern hemisphere, there is a higher likelihood of latitude being the factor affecting cloudiness when compared with the Northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Wind Speed (m/s)', 
                                   title='Northern Hemisphere (Wind Speed vs. Latitude Linear Regression)', 
                                   annotate_position=(40, 9))
# Out:
# The r-value is: -0.08586912530430695

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
create_linear_regression_plot_final(x_values, y_values, 
                                   xlabel='Latitude', 
                                   ylabel='Wind Speed (m/s)', 
                                   title='Southern Hemisphere (Wind Speed vs. Latitude Linear Regression)', 
                                   annotate_position=(-30, 20))
# Out:
# The r-value is: -0.14152872083796916

# %% [markdown]
# **Discussion about the linear relationship:**
#
# As latitude increases in the Northern hemisphere, there's a slight trend indicating a decrease in wind speed observed. This suggests a  weak negative relationship between wind speed and latitiude. It suggests that while latitude might have some effect on wind speed in the Northern hemisphere, it's not the predominant factor.
#
# As latitude increases in the Southern hemisphere, there's a trend suggesting a decrease in wind speed observed. This suggests a weak negative correlation between wind speed and latitude. While this correlation is still weak, it's slightly stronger than in the Northern Hemisphere, indicating a more pronounced (yet subtle) effect of latitude on wind speed in the Southern Hemisphere.
